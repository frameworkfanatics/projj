# %% [markdown]
# <a href="https://colab.research.google.com/github/frameworkfanatics/projj/blob/main/Summary_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import pipeline
from bs4 import BeautifulSoup
import requests

# %%
summarizer = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
URL = "https://www.blogtrovert.com/how-to-sell-canva-templates/"

# %%
r = requests.get(URL)

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US" prefix="og: http://ogp.me/ns#" prefix="og: https://ogp.me/ns#">\n<head>\n<meta charset="UTF-8" /><link rel="preconnect" href="https://fonts.gstatic.com/" crossorigin /><script>WebFontConfig={google:{families:["Asul:400,700","Hind:300,400,700"]}};if ( typeof WebFont === "object" && typeof WebFont.load === "function" ) { WebFont.load( WebFontConfig ); }</script><script data-optimized="1" src="https://www.blogtrovert.com/wp-content/plugins/litespeed-cache/assets/js/webfontloader.min.js"></script>\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<link rel="profile" href="https://gmpg.org/xfn/11">\n\n<meta name="facebook-domain-verification" content="uxg9wyqfv0ivpzjgfytwhoygsn8dai" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="How to sell Canva templates &#8211; monetize your creative designs" />\n<meta property="og:description" content="If you&
# ...

# %%
soup = BeautifulSoup(r.text,'html.parser')
results = soup.find_all(['h1', 'p'])

# %%
text = [result.text for result in results]
article = ' '.join(text)

# %%
article = article.replace('.', '.<eos>')
article = article.replace('!', '!<eos>')
article = article.replace('?', '?<eos>')
sentences = article.split('<eos>')

# %%
max_chunk =500
current_chunk =0
chunks =[]

for sentence in sentences:
  if len(chunks)== current_chunk +1:
    if len(chunks[current_chunk]) + len(sentence.split(' '))<= max_chunk:
        chunks[current_chunk].extend(sentence.split(' '))
    else:
           current_chunk +=1
           chunks.append(sentence.split(' '))
  else:
           print(current_chunk)
           chunks.append(sentence.split(' '))
# Out:
# 0

# %%
for chunk_id in range(len(chunks)):
  chunks[chunk_id] = ' '.join(chunks[chunk_id])

# %%
res = summarizer(chunks, max_length=110, min_length=30, do_sample=False)

# %%
res
# Out:
# [{'summary_text': ' Canva is a popular online platform that enables users to design professional-looking graphics . Millions of businesses and individual creatives use Canva because it’s easy to learn and relatively simple compared to other design tools like Photoshop and Illustrator . If you want to monetize your design skills by offering resources to other creators, you can learn how to sell Canva templates .'},
#  {'summary_text': ' Canva makes it a lot easier for KDP creators who are looking for better alternatives to Photoshop, InDesign and PowerPoint . Small business owners who sell printables online are always looking for ways to cut costs and save time . You, on the other hand, can grab this opportunity and monetize your creativity .'},
# ...

# %%
' '.join([summ['summary_text'] for summ in res])
# Out:
# ' Canva is a popular online platform that enables users to design professional-looking graphics . Millions of businesses and individual creatives use Canva because it’s easy to learn and relatively simple compared to other design tools like Photoshop and Illustrator . If you want to monetize your design skills by offering resources to other creators, you can learn how to sell Canva templates .  Canva makes it a lot easier for KDP creators who are looking for better alternatives to Photoshop, InDesign and PowerPoint . Small business owners who sell printables online are always looking for ways to cut costs and save time . You, on the other hand, can grab this opportunity and monetize your creativity .  Canva allows links, so you can create a single template and use it to share your designs in PDF format . The average price is between $5 and $50, but premium designs can sell for much more . When selling your templates, it is important you provide buyers with clear and concise informati
# ...

# %%
text =' '.join([summ['summary_text'] for summ in res])

# %%
with open('summaryapp.txt', 'w') as fid:
   fid.write('text')
